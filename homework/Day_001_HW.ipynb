# %% [markdown]
# 作業一:
#
#     1.我找的主題是:NBA Players stats since 1950，一方面是因為是自己的興趣，另一方面則能夠提供各種數據，讓研究者能夠分析球員個人或團隊的數值，以了解球員的個人表現。
#
#     2.球員的各項數據是由"Basketball-reference"網站所提供，其詳細記錄了球員與球隊每場比賽的各項數據。
#
#     3.共有3組資料，皆為結構化資料:
#         1)player_data.csv:欄位有姓名、生涯開始/結束年分、位置、身高、體重、生日、大學。
#         2)Player.csv:欄位有姓名、身高體重、大學、出生年月日、出生地點。
#         3)Seasons_Stats.csv:欄位有隊伍、出場時間、各項投籃數據等共53項。
#
#     4.哪個球員對該球隊是「最不可取代的球員」:替換球員差值(Value Over Replacement Player) → 數值越大，不可取代性越高，對該球隊的影響力越大 → 一但缺少該球員，該球隊會瞬間瓦解。
#
#     參考資料:https://www.kaggle.com/drgilermo/nba-players-stats#player_data.csv

# %% [markdown]
# 作業二:
#
#     1.提升業績 → 提升每月載客率、是否再次搭乘、顧客評價。
#
#     2.公司系統收集載客紀錄(時間、地點、會員、評價等)、顧客問卷調查。
#
#     3.結構化資料，欄位包含會員編號、時間、地點、評價、價格、行駛距離、會員搭乘次數等。
#
#     4.優惠活動是否提高當月載客率 → 價格&搭乘次數,ROC；評價是否影響顧客回頭率 → 搭乘次數&評價,ROC。

# %% [markdown]
# ## 練習時間
# #### 請寫一個函式用來計算 Mean Square Error
# $ MSE = \frac{1}{n}\sum_{i=1}^{n}{(Y_i - \hat{Y}_i)^2} $
#
# ### Hint: [如何取平方](https://googoodesign.gitbooks.io/-ezpython/unit-1.html)

# %%
import numpy as np
import matplotlib.pyplot as plt
import math

# %%
w = 3
b = 0.5

x_lin = np.linspace(0, 100, 101)

y = (x_lin + np.random.randn(101) * 5) * w + b

plt.plot(x_lin, y, 'b.', label = 'data points')
plt.title("Assume we have data points")
plt.legend(loc = 2)
plt.show()

# %%
y_hat = x_lin * w + b
plt.plot(x_lin, y, 'b.', label = 'data')
plt.plot(x_lin, y_hat, 'r-', label = 'prediction')
plt.title("Assume we have data points (And the prediction)")
plt.legend(loc = 2)
plt.show()

# %%
def mean_absolute_error(y, yp):
    """
    計算 MAE
    Args:
        - y: 實際值
        - yp: 預測值
    Return:
        - mae: MAE
    """
    mae = MAE = sum(abs(y - yp)) / len(y)
    return mae

# %%
def mean_squared_error(y, yp):
    """
    計算 MSE
    Args:
        - y: 實際值
        - yp: 預測值
    Return:
        - mse: MSE
    """
    mse = MSE = sum((y - yp)**2) / len(y)
    return mse

# %%
# 執行 Function, 確認有沒有正常執行
MSE = mean_squared_error(y, y_hat)
MAE = mean_absolute_error(y, y_hat)
print("The Mean squared error is %.3f" % (MSE))
print("The Mean absolute error is %.3f" % (MAE))
# Out:
# The Mean squared error is 148.761
# The Mean absolute error is 9.824
